# %%
import pandas as pd
white_house = pd.read_csv("2015_white_house.csv")
print(white_house.shape)
# Out:
# (474, 5)

# %%
print(white_house.iloc[0])
print(white_house.iloc[-1])
# Out:
# Name              Abdullah, Hasan A.
# Status                      Detailee
# Salary                        105960
# Pay Basis                  Per Annum
# Position Title        POLICY ADVISOR
# Name: 0, dtype: object
# Name                                             Zients, Jeffrey D.
# Status                                                     Employee
# Salary                                                       173922
# Pay Basis                                                 Per Annum
# Position Title    ASSISTANT TO THE PRESIDENT FOR ECONOMIC POLICY...
# Name: 473, dtype: object

# %%
white_house
# Out:
#                          Name    Status  Salary  Pay Basis  \
# 0          Abdullah, Hasan A.  Detailee  105960  Per Annum
# 1           Abraham, Sabey M.  Employee   55000  Per Annum
# 2        Abraham, Yohannes A.  Employee  121200  Per Annum
# 3          Abramson, Jerry E.  Employee  155035  Per Annum
# 4          Adler, Caroline E.  Employee  114000  Per Annum
# 5            Aiyer, Vikrum D.  Detailee  134662  Per Annum
# 6           Alcantara, Elias   Employee   65650  Per Annum
# 7            Ali, Mohammed I.  Employee   42000  Per Annum
# 8          Allen, Angelica P.  Employee   50000  Per Annum
# 9         Allen, Elizabeth M.  Employee  103000  Per Annum
# 10          Allen, Jessica L.  Employee   42844  Per Annum
# 11         Allison, Ashley R.  Employee   97000  Per Annum
# 12     Amendolare, Vincent C.  Employee   42420  Per Annum
# 13            Amuluru, Uma M.  Detailee  116804  Per Annum
# 14        Anderson, Amanda D.  Employee  126250  Per Annum
# ...

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(white_house['Salary'])
plt.show()
# Out:
# /opt/dsserver/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/dsserver/lib/python3.4/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %% [markdown]
# Quick test of various ipython functionalities. The inline thing is pretty cool.

# %% [markdown]
# # 10: Next Steps
# We encourage you to explore the dataset, and see how Jupyter can help your data analysis workflow.
#
# Here are some questions that may help you start your exploration:
#
# - How does length of employee titles correlate to salary?
# - How much does the White House pay in total salary?
# - Who are the highest and lowest paid staffers?
# - What words are the most common in titles?
#
# If you want to download the notebook to your computer to do more analysis, you can use the blue download icon above. If you click this icon, you'll be able to download an archive containing the `ipynb` file that your notebook is saved in. For this project, the normal _File -> Download As_ interface won't work, and you'll have to download using the icon.
#
# We hope this guided project has been a good experience, and please email us at hello@dataquest.io if you want to share your work!
